# %% [markdown]
# This script is where you interact with the chatbot.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Imports

# %%
import sys
import os
from scripts.agent_script import chatbot_interaction

# %%
interaction_log = list()

# %% [markdown]
# ### Chatbot interaction below

# %%
interaction_log = chatbot_interaction(None)
# Out:
# Write 'exit' to end the chat.
#  Ask your question:  monthly cost trend for 2023
# Agent response for your question 'monthly cost trend for 2023' is : Plot generated successfully.
# Write 'exit' to end the chat.
#  Ask your question:  exit
# Agent: Conversation ended.

# %%
# Check which tool was used and what conditions were applied
interaction_log
# Out:
# [{'user_question': 'What is the revenue for 2023',
#   'agent_response': 23990182.6012136,
#   'tools_used': [{'tool_name': 'aggregate_metric_simple_where',
#     'timestamp': '2026-02-16T07:37:54.588573',
#     'metadata': {'metric': 'revenue',
#      'agg': 'sum',
#      'where_clause': 'year = 2023'}}]},
#  {'user_question': 'same but for 2020',
#   'agent_response': 3717194.888306837,
#   'tools_used': [{'tool_name': 'aggregate_metric_simple_where',
#     'timestamp': '2026-02-16T07:38:06.262781',
#     'metadata': {'metric': 'revenue',
#      'agg': 'sum',
#      'where_clause': 'year = 2023'}},
#    {'tool_name': 'aggregate_metric_simple_where',
#     'timestamp': '2026-02-16T07:38:06.270281',
#     'metadata': {'metric': 'revenue',
#      'agg': 'sum',
#      'where_clause': 'year = 2020'}}]},
#  {'user_question': 'which campaing name had the highest revenue in 2022?',
#   'agent_response': "('Campaign 160', 5063448.915696843)",
#   'tools_used': [{'tool_name': 'aggregate_metric_simple_where',
#     'timestamp': '2026-02-16T07:39:05.348947',
#     'metadata': {'metric': 'revenue',
#      'agg': 'sum',
#      'where_clause': 'year = 2023'}},
#    {'tool_name': 'aggregate_metric_simple_where',
#     'timestamp': '2026-02-16T07:39:05.356203',
#     'metadata': {'metric': 'revenue',
#      'agg': 'sum',
#      'where_clause': 'year = 2020'}},
#    {'tool_name': 'aggregate_with_grouping',
#     'timestamp': '2026-02-16T07:39:06.474061',
#     'metadata': {'metric': 'revenue',
#      'agg': 'sum',
#      'where_clause': 'year = 2022'}}]},
#  {'user_question': 'give first 5 now',
#   'agent_response': ['Campaign 160',
#    'Campaign 149',
#    'Campaign 245',
#    'Campaign 293',
#    'Campaign 274'],
#   'tools_used': [{'tool_name': 'aggregate_with_grouping',
#     'timestamp': '2026-02-16T07:39:41.290674',
#     'metadata': {'metric': 'revenue',
#      'agg': 'sum',
#      'where_clause': 'year = 2022'}}]}]
