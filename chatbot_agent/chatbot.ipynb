# %% [markdown]
# This script is where you interact with the chatbot.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Imports

# %%
import sys
import pandas as pd
import os
#from scripts.utils.db import engine
from scripts.agent_script import chatbot_interaction

# %%
interaction_log = list()

# %% [markdown]
# ### Chatbot interaction below

# %%
interaction_log = chatbot_interaction(None)
# Out:
# Write 'exit' to end the chat.
#  Ask your question:  revenue for 2020
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ User: revenue for 2020                                                                                          │
# │                                                                                                                 │
# ╰─ InferenceClientModel - meta-llama/Llama-3.3-70B-Instruct ──────────────────────────────────────────────────────╯
# ────────────────────────────────────────────────── Initial plan ───────────────────────────────────────────────────
# Here are the facts I know and the plan of action that I will follow to solve the task:
# ```
# ## 1. Facts survey
# ### 1.1. Facts given in the task
# - The year for which the revenue is required: 2020
#
# ...

# %%
# Check which tool was used and what conditions were applied
interaction_log
# Out:
# [{'user_question': 'Revenue for 2022',
#   'agent_response': 30357817.329384245,
#   'tools_used': [{'tool_name': 'aggregate_metric_structured',
#     'timestamp': '2026-04-10T12:51:30.298288',
#     'metadata': {'metric': 'revenue',
#      'agg': 'sum',
#      'filters': {'year': 2022}}}]},
#  {'user_question': 'same but for 2021',
#   'agent_response': 15173138.681923429,
#   'tools_used': [{'tool_name': 'aggregate_metric_structured',
#     'timestamp': '2026-04-10T12:52:08.942423',
#     'metadata': {'metric': 'revenue',
#      'agg': 'sum',
#      'filters': {'year': 2021}}}]},
#  {'user_question': 'what is the capital of paris',
#   'agent_response': 'Paris',
#   'tools_used': []},
#  {'user_question': 'trend data for cost 2023',
#   'agent_response': 'The trend data for cost in 2023 has been plotted successfully.',
#   'tools_used': []}]
